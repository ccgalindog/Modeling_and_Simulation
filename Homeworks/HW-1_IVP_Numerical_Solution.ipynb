# %% [markdown]
# # Solución de Problemas de Valor Inicial
#
# Encuentre una aproximación a $x_{(t)}$, dado:
#
# $\dot x = f_{(t, x)}$
#
#
# $x_{(t=0)} = x_0$

# %%
import matplotlib.style
matplotlib.style.use('classic')
import numpy as np
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Método de Euler
#
# <span style="color:red"> **Explique aquí en un par de renglones el método de Euler** </span>
#
# $x_{i+1} = x_{i} + hf_{(t_i, x_i)}$

# %%
def euler( derivadas, h, tini, tfin, x0, params ):
    #  blah blah blah
    return t, x

# %% [markdown]
# ## Método de Runge-Kutta de Cuarto Orden
#
# <span style="color:red"> **Explique aquí en un par de renglones el método de Runge-Kutta** </span>
#
# $k_1 = f_{(t_i, x_i)}$
#
# $k_2 = f_{(t_i + \frac{h}{2}, x_i + \frac{k_1}{2})}$
#
# $k_3 = f_{(t_i + \frac{h}{2}, x_i + \frac{k_2}{2})}$
#
# $k_4 = f_{(t_i + h, x_i + k_3)}$
#
#
# $x_{i+1} = x_i + \frac{h}{6}(k_1 + k_2 + k_3 + k_4)$

# %%
def rk4( derivadas, h, tini, tfin, x0, params ):
    # blah blah blah
    return t, x

# %% [markdown]
# ## <span style="color:red"> Ex 1.</span> Comparación de métodos
#
# Dada la ecuación diferencial:
#
# $\dot x = ax$
#
# Siendo $a \in \Re$ una constante cualquiera. Grafique la solución analítica y las aproximaciones numéricas obtenidas con el método de Euler y con el método RK4.
#
# Varíe el paso de integración $h$ a fin de observar cómo varía la precisión de los resultados numéricos a medida que éste se hace más pequeño.

# %%
def sistema_1(t, x, a):
    # Aquí la ecuación diferencial
    return x_dot

# %%
# blah blah blah
# Invocar aquí las funciones euler y rk4 y crear la solución analítica
# blah blah blah



plt.figure()
# gráfica de analítica:
plt.plot( ----- , -----, 'black', label = 'Analytical', linewidth = 2)
# gráfica de euler:
plt.scatter( ----- , -----, c = 'crimson', label = 'Euler', s = 50)
# gráfica de rk4:
plt.scatter( ----- , ----- , c = 'royalblue', label = 'RK4', s = 50)

plt.xlim([0, tfin])
plt.ylim([-500, 15000])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## <span style="color:red">Ex 2.</span> Plano de Fase
#
# Find the state space diagram of the following differential equation for $a = -1.5$, $a = -1$, $a = -0.5$, $a = 0$ and $a = 0.1$.
#
# Dada la siguiente ecuación diferencial:
#
#
# $\dot{x} =  \bigl(\begin{smallmatrix}
# \dot x_1\\
# \dot x_2
# \end{smallmatrix}\bigr) = \bigl(\begin{smallmatrix}
# a & 0\\
# 0 & -1
# \end{smallmatrix}\bigr) \bigl(\begin{smallmatrix}
# x_1\\
# x_2
# \end{smallmatrix}\bigr)$
#
# Siendo $a \in \Re$ una constante. Dibuje el plano de fase (diagrama del espacio de estados) para los siguientes valores del parámetro $a$:
#
#  $a = -1.5$
#
#  $a = -1$
#
#  $a = -0.5$
#
#  $a = 0$
#
#  $a = 0.1$
#
# Página 127 de *Nonlinear Dynamics and Chaos - Strogatz*

# %%
def sistema_2(t, x, a):
    # Aquí la ecuación diferencial
    return x_dot

# %%
# blah blah blah
# Solucionar la ecuación diferencial muchas veces, con  diferentes condiciones iniciales y diferente valor de a
# blah blah blah
